# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from scipy import stats

from api_keys import weather_api_key
from citipy import citipy

lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 609

# %%
units = 'imperial'
base_url = 'http://api.openweathermap.org/data/2.5/weather?'
query_url = f"{base_url}appid={weather_api_key}&units={units}&q="
weather_info = pd.DataFrame({"Cities":cities})
weather_info
# Out:
#                 Cities
# 0            busselton
# 1       saint-philippe
# 2      bambous virieux
# 3                 lebu
# 4                 poum
# ..                 ...
# 604        zhanakorgan
# 605             harper
# 606      golub-dobrzyn
# 607           necochea
# 608  troitsko-pechorsk
#
# [609 rows x 1 columns]

# %%
lat = []
lng = []
temp = []
max_temp = []
humidity = []
cloudiness = []
wind = []
city_num = 0
city_num_list = []
city_used = []

for city in weather_info['Cities']:
    response = requests.get(query_url + city).json()
    
    time.sleep(1)
    
    try:
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp.append(response['main']['temp'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind.append(response['wind']['speed'])
        city_used.append(city)
        city_num = city_num + 1
        print(city_num, city)
        city_num_list.append(city_num)
    except KeyError:
        print('City Not Found')
# Out:
# 1 busselton
# 2 saint-philippe
# 3 bambous virieux
# 4 lebu
# 5 poum
# 6 dikson
# 7 rikitea
# 8 muros
# 9 punta arenas
# 10 klaksvik
# 11 ardakan
# City Not Found
# 12 kodiak
# 13 hobart
# 14 englewood
# 15 honiara
# 16 sitka
# 17 atuona
# 18 norman wells
# 19 saskylakh
# City Not Found
# 20 willmar
# 21 nanortalik
# 22 mataura
# 23 bandarbeyla
# 24 east london
# 25 kaitangata
# 26 jamestown
# 27 darnah
# 28 saint-pierre
# 29 arraial do cabo
# 30 kapaa
# 31 papetoai
# 32 ilulissat
# 33 pedernales
# 34 cristalina
# 35 bambanglipuro
# 36 tabou
# 37 ushuaia
# 38 puerto ayora
# 39 port-gentil
# 40 vaini
# 41 hermanus
# 42 qaanaaq
# 43 rosarito
# 44 port alfred
# 45 hambantota
# 46 mount gambier
# 47 ripoll
# 48 bembereke
# 49 mar del plata
# 50 kruisfontein
# 51 saint george
# 52 iralaya
# 53 bagotville
# 54 abnub
# 55 tambopata
# 56 aktau
# 57 srednekolymsk
# 58 nueva helvecia
# 59 okmulgee
# 60 sao filipe
# 61 huarmey
# 62 geraldton
# 63 husavik
# 64 nikolskoye
# City Not Found
# 65 san matias
# 66 sonkovo
# 67 hami
# 68 cape town
# 69 mahebourg
# 70 lata
# 71 qurayyat
# 72 riyadh
# 73 markapur
# 74 luderitz
# 75 fairbanks
# 76 yulara
# 77 balabag
# 78 moose factory
# 79 kawalu
# 80 dakar
# 81 lethem
# 82 codrington
# 83 hilo
# 84 victoria
# 85 bull savanna
# City Not Found
# 86 taupo
# 87 antofagasta
# 88 tessalit
# 89 butaritari
# City Not Found
# 90 saldanha
# 91 port elizabeth
# 92 batagay-alyta
# 93 acarau
# 94 banepa
# 95 albany
# 96 tilichiki
# 97 kerema
# 98 san quintin
# 99 castro
# 100 umm kaddadah
# 101 komsomolskiy
# 102 bredasdorp
# 103 uusikaupunki
# City Not Found
# 104 frunze
# 105 lompoc
# 106 saint-joseph
# City Not Found
# 107 avarua
# 108 biu
# 109 pyapon
# 110 tiksi
# City Not Found
# 111 torbay
# 112 mount isa
# City Not Found
# 113 faanui
# 114 porto santo
# 115 sovetskiy
# 116 ambilobe
# 117 dunda
# 118 port blair
# 119 tuktoyaktuk
# 120 zyryanka
# 121 anadyr
# 122 pevek
# 123 minab
# 124 ust-barguzin
# 125 new norfolk
# 126 ribeira grande
# 127 bluff
# 128 elban
# 129 georgetown
# 130 richards bay
# 131 la ronge
# 132 tuatapere
# 133 thompson
# 134 podosinovets
# 135 bantogon
# 136 piacabucu
# 137 flin flon
# 138 saint-augustin
# 139 ancud
# 140 xai-xai
# 141 grand-santi
# 142 katsuura
# 143 aklavik
# 144 tingo maria
# 145 clayton
# 146 maniitsoq
# 147 kampene
# 148 lozova
# 149 hasaki
# 150 lucea
# 151 tasiilaq
# 152 semenivka
# 153 khatanga
# 154 ankpa
# 155 olafsvik
# 156 beringovskiy
# 157 olga
# 158 portland
# 159 jalingo
# 160 ust-nera
# 161 santo antonio do ica
# 162 bayreuth
# 163 coxim
# 164 longyearbyen
# 165 yellowknife
# 166 ekhabi
# 167 bhakkar
# 168 san cristobal
# 169 sambava
# 170 aripuana
# 171 lac du bonnet
# 172 vilhena
# City Not Found
# 173 hanna
# 174 apac
# 175 mulege
# 176 suntar
# 177 santarem
# 178 hobyo
# City Not Found
# 179 casin
# 180 idenao
# 181 kalabo
# 182 waingapu
# 183 dryden
# 184 altamira
# 185 pierre
# 186 ixtapa
# 187 camacupa
# 188 ponta do sol
# 189 chapleau
# 190 port hardy
# 191 samarai
# 192 chapais
# 193 avera
# 194 cessnock
# 195 narok
# 196 jardim
# 197 college
# City Not Found
# City Not Found
# 198 cururupu
# 199 sampit
# City Not Found
# 200 kerman
# 201 roblin
# 202 san patricio
# 203 kiruna
# 204 umm lajj
# 205 ambulu
# City Not Found
# 206 taoudenni
# 207 provideniya
# 208 barrow
# 209 caravelas
# 210 erenhot
# 211 illapel
# 212 iquique
# City Not Found
# 213 mapiripan
# 214 herat
# 215 upernavik
# 216 bac lieu
# 217 vila velha
# 218 lodja
# 219 coquimbo
# 220 kiunga
# 221 norsup
# 222 mastic beach
# 223 sur
# 224 alice springs
# 225 north bend
# 226 ahipara
# 227 cuamba
# 228 skjervoy
# 229 keuruu
# 230 petropavlovsk-kamchatskiy
# 231 faya
# 232 oranjestad
# 233 los llanos de aridane
# 234 amahai
# 235 dire
# 236 dongsheng
# 237 hithadhoo
# City Not Found
# 238 limbe
# 239 cherskiy
# 240 halifax
# 241 laguna
# 242 port hedland
# City Not Found
# 243 carnarvon
# 244 songjianghe
# 245 inta
# 246 najran
# 247 bathsheba
# 248 amga
# 249 zafra
# 250 olinda
# 251 airai
# 252 markova
# City Not Found
# 253 leningradskiy
# 254 valparaiso
# City Not Found
# 255 mehamn
# 256 hofn
# 257 vestmannaeyjar
# 258 astorga
# 259 kailua
# 260 talaya
# 261 ahuimanu
# 262 guerrero negro
# 263 darab
# 264 souillac
# 265 thabazimbi
# 266 bafoulabe
# 267 newcastle
# 268 lagoa
# 269 viedma
# City Not Found
# 270 clyde river
# 271 cordoba
# 272 great falls
# 273 labuhan
# 274 chicalim
# 275 aldan
# 276 kavieng
# City Not Found
# 277 barauna
# 278 lakatoro
# 279 santa maria
# 280 port lincoln
# 281 luanda
# 282 berbera
# 283 pisco
# 284 turiacu
# 285 kutum
# 286 san ignacio
# 287 tabuk
# 288 vung tau
# 289 matara
# 290 kirakira
# City Not Found
# 291 san pedro
# 292 alugan
# City Not Found
# 293 te anau
# City Not Found
# 294 tyrma
# 295 rawson
# 296 deputatskiy
# 297 sayyan
# 298 lixourion
# 299 meulaboh
# 300 agapovka
# 301 broome
# 302 port keats
# 303 coronel fabriciano
# 304 milkovo
# 305 klang
# 306 bengkulu
# 307 bima
# City Not Found
# 308 zapolyarnyy
# City Not Found
# 309 sisimiut
# 310 chuy
# 311 bardiyah
# 312 iqaluit
# 313 salobrena
# 314 tanout
# 315 narsaq
# 316 gat
# 317 hamilton
# 318 lahij
# 319 bethel
# 320 biak
# 321 sioux lookout
# 322 cabo san lucas
# 323 kimbe
# 324 copiapo
# 325 litovko
# 326 puerto del rosario
# City Not Found
# 327 teguldet
# 328 roald
# 329 salalah
# 330 namatanai
# City Not Found
# 331 severo-kurilsk
# 332 caruray
# 333 noyabrsk
# 334 esperance
# 335 tiarei
# City Not Found
# City Not Found
# 336 the valley
# 337 sompeta
# 338 amreli
# City Not Found
# 339 crestview
# City Not Found
# 340 westerland
# City Not Found
# 341 luwuk
# 342 leszno
# 343 asosa
# 344 ifo
# 345 fortuna
# 346 kisangani
# 347 abu dhabi
# 348 patea
# 349 derzhavinsk
# 350 chokurdakh
# 351 chernyshevskiy
# 352 vardo
# 353 qui nhon
# 354 panaba
# 355 conakry
# 356 akyab
# 357 plouzane
# 358 vao
# 359 teya
# 360 ponta delgada
# 361 tual
# 362 mahajanga
# 363 qaqortoq
# 364 quebrangulo
# 365 kingsville
# 366 ayan
# 367 mezen
# 368 sirohi
# 369 ocean city
# 370 jinchang
# 371 aloleng
# 372 asau
# 373 coahuayana
# 374 staryy nadym
# 375 susuman
# 376 taltal
# 377 tena
# 378 shingu
# 379 byron bay
# City Not Found
# 380 mossendjo
# 381 pangnirtung
# 382 xam nua
# 383 turtas
# 384 preston
# 385 tyukhtet
# 386 tucuma
# 387 dakoro
# 388 khandyga
# City Not Found
# 389 shambu
# 390 saint-louis
# 391 hokitika
# 392 pasaquina
# 393 tungi
# 394 machali
# 395 wembley
# 396 zhezkazgan
# 397 havoysund
# 398 kloulklubed
# 399 emerald
# 400 chingirlau
# 401 daru
# 402 bereda
# 403 requena
# 404 manteca
# 405 okhotsk
# 406 natal
# 407 haines junction
# 408 oudtshoorn
# 409 manicore
# 410 texas city
# 411 teknaf
# City Not Found
# 412 ostrovnoy
# 413 vallenar
# 414 seoul
# 415 namibe
# 416 ustka
# 417 poronaysk
# 418 road town
# 419 pemba
# 420 marrakesh
# 421 soledad
# 422 calceta
# 423 mwense
# 424 mahanje
# 425 chenghai
# City Not Found
# 426 abancay
# 427 sloboda
# 428 bilibino
# 429 rabat
# 430 oranjemund
# 431 russell
# 432 mayumba
# 433 shimoda
# 434 concepcion
# 435 binga
# City Not Found
# 436 maine-soroa
# 437 sola
# 438 saint anthony
# City Not Found
# 439 aksarka
# 440 omutninsk
# 441 zhanaozen
# City Not Found
# 442 hualmay
# 443 biltine
# City Not Found
# 444 cabedelo
# 445 sao tome
# 446 manggar
# 447 narimanov
# 448 qasigiannguit
# 449 pyu
# 450 guymon
# 451 semnan
# 452 bermejo
# 453 raudeberg
# City Not Found
# City Not Found
# 454 vila franca do campo
# City Not Found
# 455 tezu
# City Not Found
# 456 inuvik
# 457 fuerte olimpo
# 458 suifenhe
# 459 rtishchevo
# City Not Found
# 460 andapa
# 461 dunhua
# 462 palma soriano
# 463 tucdao
# 464 rio grande
# 465 nome
# 466 yagodnoye
# 467 kenai
# 468 mayor pablo lagerenza
# 469 reconquista
# 470 kavaratti
# 471 esso
# 472 aksu
# 473 soyo
# 474 alofi
# 475 carolina
# 476 lasa
# City Not Found
# 477 ugoofaaru
# 478 chodavaram
# 479 nabire
# 480 shama
# 481 sokode
# 482 grindavik
# 483 kaizuka
# 484 morondava
# 485 vieques
# 486 grajau
# City Not Found
# 487 limoux
# 488 san jose
# 489 black diamond
# 490 novyy buh
# 491 urucara
# 492 seoni
# 493 verkhoyansk
# 494 ramhormoz
# 495 arrifes
# 496 harnai
# 497 yar-sale
# 498 bodden town
# 499 pampa
# 500 welver
# 501 margate
# 502 havelock
# 503 muswellbrook
# 504 dingle
# 505 flinders
# 506 luganville
# 507 picota
# 508 tura
# 509 san policarpo
# 510 yaan
# 511 port shepstone
# 512 tiznit
# 513 ballina
# 514 barcelos
# 515 nouakchott
# 516 marienburg
# 517 semey
# 518 nhulunbuy
# 519 bairiki
# 520 makinsk
# 521 shellbrook
# 522 nantucket
# 523 pahrump
# 524 hegang
# 525 brookhaven
# 526 langham
# 527 dawlatabad
# 528 ketchikan
# 529 ploemeur
# 530 san vicente de canete
# 531 winnemucca
# 532 imbituba
# 533 vanderhoof
# 534 kahului
# 535 birjand
# 536 tartus
# 537 banyo
# 538 tahe
# 539 chunskiy
# 540 barranca
# 541 karachi
# 542 berlevag
# 543 havre-saint-pierre
# 544 constantine
# 545 karpathos
# 546 santa isabel do rio negro
# 547 turukhansk
# 548 peniche
# 549 rafaela
# 550 alekseyevsk
# 551 parkersburg
# 552 batsfjord
# 553 nelson bay
# 554 kainantu
# 555 vostok
# 556 zhanakorgan
# 557 harper
# 558 golub-dobrzyn
# 559 necochea
# 560 troitsko-pechorsk

# %%
weather_df = pd.DataFrame({'City':city_used, 'Latitude':lat, 'Longitude':lng, 'Temperature (F)':temp, 'Max Temperature (F)': max_temp,
                           'Humidity (%)':humidity, 'Cloudiness (%)':cloudiness, 'Wind Speed (MPH)':wind})
weather_df
# Out:
#                   City  Latitude  Longitude  Temperature (F)  \
# 0            busselton    -33.65     115.33            76.51
# 1       saint-philippe    -21.36      55.77            72.79
# 2      bambous virieux    -20.34      57.76            77.45
# 3                 lebu    -37.62     -73.65            59.02
# 4                 poum    -20.23     164.02            79.88
# ..                 ...       ...        ...              ...
# 555        zhanakorgan     43.91      67.25            30.40
# 556             harper      4.38      -7.72            77.07
# 557      golub-dobrzyn     53.11      19.05            45.43
# 558           necochea    -38.55     -58.74            57.76
# 559  troitsko-pechorsk     62.71      56.20            14.94
#
#      Max Temperature (F)  Humidity (%)  Cloudiness (%)  Wind Speed (MPH)
# 0                  79.00            20               0              8.99
# 1                  77.00            88               0              6.93
# 2                  78.01            88              75              9.17
# 3                  59.02            71               0              8.63
# 4                  79.88            84             100             38.72
# ..                   ...           ...             ...               ...
# 555                30.40            82             100              5.73
# 556                77.07            91               3              2.95
# 557                46.99            79             100              3.00
# 558                60.01            73             100              4.00
# 559                14.94            94             100              6.67
#
# [560 rows x 8 columns]

# %%
output_data = "../output_data/cities.csv"
weather_df.to_csv(output_data)

# %%
weather_df = pd.read_csv(output_data)

# %%
weather_df.plot(kind = 'scatter', x = 'Latitude', y = 'Temperature (F)', marker = 'o')
plt.title('Temperature vs. Latitude')
plt.ylabel('Temperature in Degrees Fahrenheit')
plt.grid()
plt.savefig("Chart 1")

# %% [markdown]
# There is a very evident negative correlation between latitude and temperature. As the latitude goes up, temperature comes down. This makes total sense because as you go north, temperature tends to come down.

# %%
weather_df.plot(kind = 'scatter', x = 'Latitude', y = 'Humidity (%)', marker = 'o')
plt.title('Humidity vs. Latitude')
plt.ylabel('Humidity (%)')
plt.grid()
plt.savefig("Chart 2")

# %% [markdown]
# There seems to be no correlation between humidity and latitude. If you look closely, we could draw a slight positive correlation but it's definitely not strong enough to make any conclusions. Again, it does make sense for warmer climates to have more humidity.

# %%
weather_df.plot(kind = 'scatter', x = 'Latitude', y = 'Cloudiness (%)', marker = 'o')
plt.title('Cloudiness vs. Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()
plt.savefig("Chart 3")

# %% [markdown]
# There is absolutely no sign of correlation between latitude and cloudiness. If you think about it, this makes sense. I feel like cloudiness is one of those weather conditions where there are too many external factors that play into it.

# %%
weather_df.plot(kind = 'scatter', x = 'Latitude', y = 'Wind Speed (MPH)', marker = 'o')
plt.title('Wind Speed vs. Latitude')
plt.ylabel('Wind Speed (MPH)')
plt.grid()
plt.savefig("Chart 4")

# %% [markdown]
# Wind speed is different from cloudiness that it's pretty consistent across both sides of the equator. I see a very small negative correlation but I can't draw decisive conclusions between the two metrics.

# %%
def north_regression(y_variable):
    x_values = north_weather['Latitude']
    y_values = north_weather[y_variable]
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    north_weather.plot(kind = 'scatter', x = 'Latitude', y = y_variable, marker = 'o')
    plt.title(y_variable +' vs. Latitude')
    plt.ylabel(y_variable)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.grid()
    plt.plot(x_values, regress_values,"r-")
    print(f"R-value equals {str(rvalue)}")
    print(line_eq)
    
def south_regression(y_variable):
    x_values = south_weather['Latitude']
    y_values = south_weather[y_variable]
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    south_weather.plot(kind = 'scatter', x = 'Latitude', y = y_variable, marker = 'o')
    plt.title(y_variable +' vs. Latitude')
    plt.ylabel(y_variable)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.grid()
    plt.plot(x_values, regress_values,"r-")
    print(f"R-value equals {str(rvalue)}")
    print(line_eq)

# %%
# Create Northern and Southern Hemisphere DataFrames
north_weather = weather_df.loc[weather_df['Latitude']>0]
south_weather = weather_df.loc[weather_df['Latitude']<0]

# %%
north_regression('Temperature (F)')
plt.savefig("Chart 5")
# Out:
# R-value equals -0.8774826523705975
# y = -1.31x + 90.8

# %%
south_regression('Temperature (F)')
plt.savefig("Chart 6")
# Out:
# R-value equals 0.44846885748952775
# y = 0.34x + 80.73

# %%
north_regression('Humidity (%)')
plt.savefig("Chart 7")
# Out:
# R-value equals 0.3849590354190076
# y = 0.4x + 56.39

# %%
south_regression('Humidity (%)')
plt.savefig("Chart 8")
# Out:
# R-value equals 0.2299840260361685
# y = 0.31x + 84.02

# %%
north_regression('Cloudiness (%)')
plt.savefig("Chart 9")
# Out:
# R-value equals 0.29822346275079514
# y = 0.58x + 29.54

# %%
south_regression('Cloudiness (%)')
plt.savefig("Chart 10")
# Out:
# R-value equals 0.48413543944076093
# y = 1.44x + 85.62

# %%
north_regression('Wind Speed (MPH)')
plt.savefig("Chart 11")
# Out:
# R-value equals 0.11527505970192478
# y = 0.04x + 8.02

# %%
south_regression('Wind Speed (MPH)')
plt.savefig("Chart 12")
# Out:
# R-value equals -0.2841728663368354
# y = -0.13x + 5.39
